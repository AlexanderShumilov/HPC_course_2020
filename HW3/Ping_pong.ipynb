# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def speedup(a, b):
    return [b[i]/a[i] for i in range(len(a))]

# %%
df = pd.read_csv('Table.txt', sep="\t", error_bad_lines=False)

# %%
df.head(11)
# Out:
#     Size(bytes)  # Iterations  Totaltime(secs)  Time per message  \
# 0           360      17447525        25.000003          0.000001
# 1           630      15345462        25.000006          0.000002
# 2           900      16334001        25.000006          0.000002
# 3          1170      14849189        25.000006          0.000002
# 4          1440      15291407        25.000001          0.000002
# 5          1710      14666886        25.000003          0.000002
# 6          1980      15094292        25.000002          0.000002
# 7          2250      13337743        25.000003          0.000002
# 8          2520      13577154        25.000003          0.000002
# 9          2790      13250033        25.000003          0.000002
# 10         3060      13255867        25.000004          0.000002
#
#     Bandwidth(MB/s)
# 0        239.605265
# 1        368.791147
# 2        560.783292
# 3        662.748217
# 4        839.982032
# 5        956.740273
# 6       1140.086983
# ...

# %%
df.tail(10)
# Out:
#     Size(bytes)  # Iterations  Totaltime(secs)  Time per message  \
# 90        24660       4417170        25.000000          0.000006
# 91        24930       4730787        25.000012          0.000005
# 92        25200       4310867        25.000005          0.000006
# 93        25470       4206178        25.000011          0.000006
# 94        25740       4308272        25.000003          0.000006
# 95        26010       4328955        25.000025          0.000006
# 96        26280       4327486        25.000014          0.000006
# 97        26550       4270828        25.000022          0.000006
# 98        26820       4474458        25.000008          0.000006
# 99        27090       4524249        25.000012          0.000006
#
#     Bandwidth(MB/s)
# 90      4155.250991
# 91      4498.995391
# 92      4144.051567
# 93      4086.734942
# 94      4230.305059
# 95      4295.196876
# 96      4338.312767
# 97      4325.499849
# 98      4577.824564
# 99      4675.363433

# %%
plt.figure(figsize = (8,8))

plt.plot(df["Size(bytes)"], df["Bandwidth(MB/s)"], '.-', lw = 2)

plt.grid('on')
plt.xlabel("Size(bytes)", fontsize = 16)
plt.ylabel('Bandwidth(MB/s)', fontsize = 16)

plt.show()
plt.savefig('HW3.png')

# %% [markdown]
# After 20000 everything stops actually change much
